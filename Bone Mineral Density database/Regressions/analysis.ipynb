# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load datasets
advertising = pd.read_csv('advertising.csv')
bank = pd.read_csv('bank.csv')
standard_errors = pd.read_csv('standard_errors_example.csv')

print(advertising.head())
print(bank.head())
print(standard_errors.head())
